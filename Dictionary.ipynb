# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/AIML-/blob/project/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declaring a dictionary
student = {
    "name": "Alex",
    "age": 21,
    "branch": "Machine Learning"
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Alex', 'age': 21, 'branch': 'Machine Learning'}

# %% [markdown]
#  **Functions of Dictionary**

# %%
#get()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Fetch existing key
print(person.get("name"))
# Fetch non-existing key
print(person.get("country"))
# Out:
# Alex
# None

# %%
#key()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Get all keys
print(person.keys())
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
#values()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Get all values
print(person.values())
# Out:
# dict_values(['Alex', 25, 'Mumbai'])

# %%
#items()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Get all key-value pairs
print(person.items())
# Out:
# dict_items([('name', 'Alex'), ('age', 25), ('city', 'Mumbai')])

# %%
#update()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Update dictionary with new data
person.update({"age": 26, "country": "India"})
print(person)
# Out:
# {'name': 'Alex', 'age': 26, 'city': 'Mumbai', 'country': 'India'}

# %%
#pop()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Remove a key and get its value
removed_value = person.pop("city")
print("Removed value:", removed_value)
print(person)
# Out:
# Removed value: Mumbai
# {'name': 'Alex', 'age': 25}

# %%
#popitem()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Remove last inserted item
last_item = person.popitem()
print("Removed last item:", last_item)
print(person)
# Out:
# Removed last item: ('city', 'Mumbai')
# {'name': 'Alex', 'age': 25}

# %%
#clear()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Clear dictionary
person.clear()
print(person)
# Out:
# {}

# %%
#copy()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Make a copy
person_copy = person.copy()
print("Copy:", person_copy)
# Out:
# Copy: {'name': 'Alex', 'age': 25, 'city': 'Mumbai'}

# %%
#setdefault()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Get value if exists, else set a default
value = person.setdefault("country", "India")
print(person)
# Out:
# {'name': 'Alex', 'age': 25, 'city': 'Mumbai', 'country': 'India'}

# %%
#del()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
# Delete a specific key
del person["age"]
print(person)
# Out:
# {'name': 'Alex', 'city': 'Mumbai'}

# %%
#del()
person = {"name": "Alex", "age": 25, "city": "Mumbai"}
del person

# %% [markdown]
# Given a list of numbers, count how many times each number occurs using a dictionary

# %%
numbers = [1, 2, 2, 3, 3, 3, 4]
frequency = {}
for num in numbers:
    if num in frequency:
        frequency[num] += 1
    else:
        frequency[num] = 1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1}

# %% [markdown]
# Find the Key with Maximum Value

# %%
marks = {"John": 45, "Emma": 88, "Noah": 77}
# Find key with maximum value
topper = max(marks, key=marks.get)
print("Topper is:", topper)
# Out:
# Topper is: Emma

# %% [markdown]
# Merge Two Dictionaries

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"b": 3, "c": 4}
# Merge using update()
dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# Invert a Dictionary (Swap Keys and Values)

# %%
original = {'a': 1, 'b': 2, 'c': 3}
inverted = {}
for key, value in original.items():
    inverted[value] = key
print(inverted)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# Check if Two Dictionaries are Equal

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"b": 2, "a": 1}

# Compare directly
print(dict1 == dict2)

# Another Example
dict3 = {"a": 2, "b": 1}
print(dict1 == dict3)
# Out:
# True
# False
