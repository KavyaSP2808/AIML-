# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/AIML-/blob/project/Queue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#declaring Queue using Python List
queue = []
print("Initial queue:", queue)
# Out:
# Initial queue: []

# %% [markdown]
# **Functions in Queue**

# %%
#enqueue()
queue = []
queue.append(10)
queue.append(20)
queue.append(30)
print("Queue after enqueues:", queue)
# Out:
# Queue after enqueues: [10, 20, 30]

# %%
#dequeue()
queue = [10, 20, 30]
removed = queue.pop(0)
print("Removed element:", removed)
print("Queue after dequeue:", queue)
# Out:
# Removed element: 10
# Queue after dequeue: [20, 30]

# %%
#peek()
queue = [10, 20, 30]
print("Front element:", queue[0])
# Out:
# Front element: 10

# %%
#isempty()
queue = []
print("Is queue empty?", len(queue) == 0)
# Out:
# Is queue empty? True

# %%
#size()
queue = [10, 20, 30]
print("Size of queue:", len(queue))
# Out:
# Size of queue: 3

# %%
class Queue:
    def __init__(self):
        self.queue = []

    # Enqueue operation
    def enqueue(self, item):
        self.queue += [item]

    # Dequeue operation
    def dequeue(self):
        if not self.isEmpty():
            front_element = self.queue[0]
            self.queue = self.queue[1:]  # remove first element manually
            return front_element
        else:
            return "Queue Underflow"

    # Peek operation
    def peek(self):
        if not self.isEmpty():
            return self.queue[0]
        else:
            return "Queue is empty"

    # isEmpty operation
    def isEmpty(self):
        return len(self.queue) == 0

    # size operation
    def size(self):
        return len(self.queue)

    # display queue
    def display(self):
        return self.queue


# Example usage:
q = Queue()
print("Initial queue:", q.display())
q.enqueue(10)
q.enqueue(20)
q.enqueue(30)
print("Queue after enqueues:", q.display())
print("Front element (peek):", q.peek())
print("Removed element (dequeue):", q.dequeue())
print("Queue after dequeue:", q.display())
print("Is queue empty?", q.isEmpty())
print("Queue size:", q.size())
# Out:
# Initial queue: []
# Queue after enqueues: [10, 20, 30]
# Front element (peek): 10
# Removed element (dequeue): 10
# Queue after dequeue: [20, 30]
# Is queue empty? False
# Queue size: 2

# %% [markdown]
# **Implement a Queue Using Two Stacks**

# %%
class QueueUsingStacks:
    def __init__(self):
        self.stack1 = []
        self.stack2 = []

    def enqueue(self, item):
        self.stack1.append(item)

    def dequeue(self):
        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())
        if not self.stack2:
            return "Queue Underflow"
        return self.stack2.pop()

# Example
q = QueueUsingStacks()
q.enqueue(10)
q.enqueue(20)
q.enqueue(30)
print(q.dequeue())
# Out:
# 10

# %% [markdown]
# **Generate Binary Numbers from 1 to N**

# %%
from collections import deque

def generateBinaryNumbers(N):
    result = []
    queue = deque()
    queue.append("1")

    for _ in range(N):
        front = queue.popleft()
        result.append(front)
        queue.append(front + "0")
        queue.append(front + "1")

    return result

# Example
print(generateBinaryNumbers(5))
# Out:
# ['1', '10', '11', '100', '101']

# %% [markdown]
# **First Non-Repeating Character in a Stream**

# %%
from collections import deque

def firstNonRepeating(stream):
    freq = {}
    queue = deque()
    result = []

    for ch in stream:
        freq[ch] = freq.get(ch, 0) + 1
        queue.append(ch)

        while queue and freq[queue[0]] > 1:
            queue.popleft()

        result.append(queue[0] if queue else '-1')

    return result

# Example
stream = "aabc"
print(firstNonRepeating(stream))
# Out:
# ['a', '-1', 'b', 'b']

# %% [markdown]
# **Reverse a Queue**

# %%
from collections import deque

def reverseQueue(queue):
    if not queue:
        return
    front = queue.popleft()
    reverseQueue(queue)
    queue.append(front)

# Example
q = deque([10, 20, 30, 40])
reverseQueue(q)
print(list(q))
# Out:
# [40, 30, 20, 10]
