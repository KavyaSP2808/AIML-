# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/AIML-/blob/project/Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#declaring a set
my_set = {1, 2, 3, 4, 5}
print("Initial Set:", my_set)
# Out:
# Initial Set: {1, 2, 3, 4, 5}

# %% [markdown]
# **Functions in Set**

# %%
#add()
my_set = {1, 2, 3}
my_set.add(4)
print("After add:", my_set)
# Out:
# After add: {1, 2, 3, 4}

# %%
#update()
my_set = {1, 2}
my_set.update([3, 4, 5])
print("After update:", my_set)
# Out:
# After update: {1, 2, 3, 4, 5}

# %%
#remove()
my_set = {1, 2, 3}
my_set.remove(2)
print("After remove:", my_set)
# Out:
# After remove: {1, 3}

# %%
#discard()
my_set = {1, 2, 3}
my_set.discard(5)
print("After discard:", my_set)
# Out:
# After discard: {1, 2, 3}

# %%
#pop()
my_set = {10, 20, 30}
removed_item = my_set.pop()
print("Removed item:", removed_item)
print("After pop:", my_set)
# Out:
# Removed item: 10
# After pop: {20, 30}

# %%
#clear()
my_set = {1, 2, 3}
my_set.clear()
print("After clear:", my_set)
# Out:
# After clear: set()

# %%
#union()
set1 = {1, 2, 3}
set2 = {3, 4, 5}
result = set1.union(set2)
print("Union:", result)
# Out:
# Union: {1, 2, 3, 4, 5}

# %%
#intersection()
set1 = {1, 2, 3}
set2 = {2, 3, 4}
result = set1.intersection(set2)
print("Intersection:", result)
# Out:
# Intersection: {2, 3}

# %%
#symmetric_difference()
set1 = {1, 2, 3}
set2 = {2, 3, 4}
result = set1.symmetric_difference(set2)
print("Symmetric Difference:", result)
# Out:
# Symmetric Difference: {1, 4}

# %%
#issubset()
set1 = {1, 2}
set2 = {1, 2, 3}
print("Is set1 subset of set2?", set1.issubset(set2))
# Out:
# Is set1 subset of set2? True

# %%
#isupperset
set1 = {1, 2, 3}
set2 = {2, 3}
print("Is set1 superset of set2?", set1.issuperset(set2))
# Out:
# Is set1 superset of set2? True

# %%
#len()
my_set = {10, 20, 30, 40}
print("Length of set:", len(my_set))
# Out:
# Length of set: 4

# %% [markdown]
# Remove Duplicates from a List Using Set

# %%
numbers = [1, 2, 3, 2, 4, 1, 5]
# Remove duplicates by converting list to set and back to list
unique_numbers = list(set(numbers))
print("Unique numbers:", unique_numbers)
# Out:
# Unique numbers: [1, 2, 3, 4, 5]

# %% [markdown]
# Check if Two Sets Have Common Elements

# %%
set1 = {1, 2, 3}
set2 = {4, 5, 6}
# Check for common elements
if set1.intersection(set2):
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# Find Elements Present in Only One of the Two Sets

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
# Symmetric difference gives elements not common to both
result = set1.symmetric_difference(set2)
print("Elements unique to either set:", result)
# Out:
# Elements unique to either set: {1, 2, 4, 5}

# %% [markdown]
# Count the Number of Unique Characters in a String

# %%
text = "hello"
# Convert string to set to get unique characters
unique_chars = set(text)
print("Number of unique characters:", len(unique_chars))
# Out:
# Number of unique characters: 4

# %% [markdown]
# Check if One Set is a Subset of Another

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}
# Check if set1 is subset of set2
print("Is set1 a subset of set2?", set1.issubset(set2))
# Out:
# Is set1 a subset of set2? True
