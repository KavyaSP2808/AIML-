# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/AIML-/blob/project/tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a tuple
my_tuple = (10, 20, 30, 40, 50)
# Display the tuple
print("Tuple:", my_tuple)
# Out:
# Tuple: (10, 20, 30, 40, 50)

# %% [markdown]
# **Functions**

# %%
#index()
my_tuple = (10, 20, 30, 20, 40)
# Find index of first occurrence of 20
index_of_20 = my_tuple.index(20)
print("Index of 20:", index_of_20)
# Out:
# Index of 20: 1

# %%
#count()
my_tuple = (10, 20, 10, 30, 10, 40)
# Count how many times 10 appears
count_10 = my_tuple.count(10)
print("Count of 10:", count_10)
# Out:
# Count of 10: 3

# %%
#len()
my_tuple = (10, 20, 30, 40)
# Find the length
length = len(my_tuple)
print("Length of tuple:", length)
# Out:
# Length of tuple: 4

# %%
#min()
#max()
my_tuple = (10, 20, 30, 40)
# Find max and min values
maximum_value = max(my_tuple)
minimum_value = min(my_tuple)
print("Max value:", maximum_value)
print("Min value:", minimum_value)
# Out:
# Max value: 40
# Min value: 10

# %%
#sum()
my_tuple = (10, 20, 30, 40)
# Calculate sum
total = sum(my_tuple)
print("Sum of tuple:", total)
# Out:
# Sum of tuple: 100

# %%
#tuple()
my_list = [10, 20, 30, 40]
# Convert to tuple
my_tuple = tuple(my_list)
print("Converted tuple:", my_tuple)
# Out:
# Converted tuple: (10, 20, 30, 40)

# %% [markdown]
# Given a tuple of numbers and a target element, find and print all indexes where the target element occurs in the tuple.

# %%
my_tuple = (10, 20, 30, 20, 40, 20)
target = 20
indexes = []
for i in range(len(my_tuple)):
    if my_tuple[i] == target:
        indexes.append(i)
print(indexes)
# Out:
# [1, 3, 5]

# %% [markdown]
# Flatten a Tuple of Tuples

# %%
nested_tuple = ((1, 2), (3, 4), (5, 6))
flat_list = []
for t in nested_tuple:
    for num in t:
        flat_list.append(num)
flat_tuple = tuple(flat_list)
print(flat_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Swap First and Last Elements

# %%
my_tuple = (10, 20, 30, 40)
temp = list(my_tuple)
temp[0], temp[-1] = temp[-1], temp[0]
new_tuple = tuple(temp)
print(new_tuple)
# Out:
# (40, 20, 30, 10)

# %% [markdown]
# Find Second Largest Element

# %%
my_tuple = (10, 40, 30, 20, 50)
my_list = list(my_tuple)
my_list.sort()
print(my_list)
second_largest = my_list[3]
print(second_largest)
# Out:
# [10, 20, 30, 40, 50]
# 40

# %% [markdown]
# Check if Two Tuples are Identical

# %%
tuple1 = (10, 20, 30)
tuple2 = (10, 20, 30)
print(tuple1 == tuple2)
# Out:
# True
